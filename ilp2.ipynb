# %% [markdown]
# <a href="https://colab.research.google.com/github/arunkumarbhagat/IPL-Prediction-Model/blob/main/ilp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
match= pd.read_csv('/content/matches[2].csv')
delivery= pd.read_csv('/content/deliveries[1].csv')

# %%
match.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
match.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
delivery.isnull().sum()
# Out:
# match_id                0
# inning                  0
# batting_team            0
# bowling_team            0
# over                    0
# ball                    0
# batter                  0
# bowler                  0
# non_striker             1
# batsman_runs            1
# extra_runs              1
# total_runs              1
# extras_type         86946
# is_wicket               1
# player_dismissed    87490
# dismissal_kind      87490
# fielder             88771
# dtype: int64

# %%
delivery.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum           0.0         1.0
# 1     2  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
# 2     3  BB McCullum  P Kumar   SC Ganguly           0.0         1.0
# 3     4  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
# 4     5  BB McCullum  P Kumar   SC Ganguly           0.0         0.0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
delivery.groupby(['match_id','inning']).sum()['total_runs']
# Out:
# match_id  inning
# 335982    1         222.0
#           2          82.0
# 335983    1         240.0
#           2         207.0
# 335984    1         129.0
#                     ...
# 598061    1         170.0
#           2         163.0
# 598062    1         168.0
#           2         135.0
# 598063    1          35.0
# Name: total_runs, Length: 782, dtype: float64

# %%
total_score_df=delivery.groupby(['match_id','inning']).sum()['total_runs']+1

# %%
total_score_df
# Out:
# match_id  inning
# 335982    1         223.0
#           2          83.0
# 335983    1         241.0
#           2         208.0
# 335984    1         130.0
#                     ...
# 598061    1         171.0
#           2         164.0
# 598062    1         169.0
#           2         136.0
# 598063    1          36.0
# Name: total_runs, Length: 782, dtype: float64

# %%
match.shape
# Out:
# (1095, 20)

# %%
delivery.shape
# Out:
# (92042, 17)

# %%
total_score_df =total_score_df[total_score_df.index.get_level_values('inning')==1]

# %%
total_score_df
# Out:
# match_id  inning
# 335982    1         223.0
# 335983    1         241.0
# 335984    1         130.0
# 335985    1         166.0
# 335986    1         111.0
#                     ...
# 598059    1         121.0
# 598060    1         179.0
# 598061    1         171.0
# 598062    1         169.0
# 598063    1          36.0
# Name: total_runs, Length: 388, dtype: float64

# %%
match.merge(total_score_df.reset_index()[['match_id','total_runs']],left_on='id',right_on='match_id')
# Out:
#          id   season        city        date match_type player_of_match  \
# 0    335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1    335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2    335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3    335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4    335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# ..      ...      ...         ...         ...        ...             ...
# 383  598045     2013   Bangalore  2013-05-14     League    AC Gilchrist
# 384  598062     2013     Chennai  2013-05-14     League        MS Dhoni
# 385  598061     2013      Ranchi  2013-05-15     League       MK Pandey
# 386  598063     2013      Mumbai  2013-05-15     League         AP Tare
# 387  598028     2013  Dharamsala  2013-05-16     League       DA Miller
#
#                                             venue  \
# 0                           M Chinnaswamy Stadium
# ...

# %%
match_df=match.merge(total_score_df.reset_index()[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 0
# date                 0
# match_type           0
# player_of_match      1
# venue                0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               1
# result               0
# result_margin        5
# target_runs          1
# target_overs         1
# super_over           0
# method             380
# umpire1              0
# umpire2              0
# match_id             0
# total_runs           0
# dtype: int64

# %%
match_df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad'],
#       dtype=object)

# %%
teams = [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bangalore',
    'Kolkata Knight Riders',
    'Kings XI Punjab',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals',
    'Gujarat Titans',
    'Lucknow Super Giants',

]

# %%
match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils', 'Delhi Capitals')
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils', 'Delhi Capitals')

match_df['team1'] = match_df['team1'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')

# %%
match_df = match_df[match_df['team1'].isin(teams)]
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df.shape
# Out:
# (330, 22)

# %%
match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 330 entries, 0 to 387
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               330 non-null    int64
#  1   season           330 non-null    object
#  2   city             330 non-null    object
#  3   date             330 non-null    object
#  4   match_type       330 non-null    object
#  5   player_of_match  330 non-null    object
#  6   venue            330 non-null    object
#  7   team1            330 non-null    object
#  8   team2            330 non-null    object
#  9   toss_winner      330 non-null    object
#  10  toss_decision    330 non-null    object
#  11  winner           330 non-null    object
#  12  result           330 non-null    object
#  13  result_margin    326 non-null    float64
#  14  target_runs      330 non-null    float64
#  15  target_overs     330 non-null    float64
#  16  super_over       330 non-null    object
# ...

# %%
match_df=match_df[['match_id','city','winner','total_runs']]

# %%
delivery_df=match_df.merge(delivery,on='match_id')

# %%
delivery_df.isnull().sum()
# Out:
# match_id                0
# city                    0
# winner                  0
# total_runs_x            0
# inning                  0
# batting_team            0
# bowling_team            0
# over                    0
# ball                    0
# batter                  0
# bowler                  0
# non_striker             1
# batsman_runs            1
# extra_runs              1
# total_runs_y            1
# extras_type         74013
# is_wicket               1
# player_dismissed    74558
# dismissal_kind      74558
# fielder             75639
# dtype: int64

# %%
delivery_df
# Out:
#        match_id        city                 winner  total_runs_x  inning  \
# 0        335982   Bangalore  Kolkata Knight Riders         223.0       1
# 1        335982   Bangalore  Kolkata Knight Riders         223.0       1
# 2        335982   Bangalore  Kolkata Knight Riders         223.0       1
# 3        335982   Bangalore  Kolkata Knight Riders         223.0       1
# 4        335982   Bangalore  Kolkata Knight Riders         223.0       1
# ...         ...         ...                    ...           ...     ...
# 78437    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78438    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78439    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78440    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78441    598028  Dharamsala        Kings XI Punjab         172.0       2
#
#                 batting_team                 bowling_team  over  ball  \
# ...

# %%
delivery_df=delivery_df[delivery_df['inning']==2]

# %%
delivery_df.shape
# Out:
# (37865, 20)

# %%
delivery_df['current_score']=delivery_df.groupby(['match_id'])['total_runs_y'].cumsum()
# Out:
# <ipython-input-32-61ebf5f5189f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['current_score']=delivery_df.groupby(['match_id'])['total_runs_y'].cumsum()

# %%
delivery_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37865 entries, 124 to 78441
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          37865 non-null  int64
#  1   city              37865 non-null  object
#  2   winner            37865 non-null  object
#  3   total_runs_x      37865 non-null  float64
#  4   inning            37865 non-null  int64
#  5   batting_team      37865 non-null  object
#  6   bowling_team      37865 non-null  object
#  7   over              37865 non-null  int64
#  8   ball              37865 non-null  int64
#  9   batter            37865 non-null  object
#  10  bowler            37865 non-null  object
#  11  non_striker       37865 non-null  object
#  12  batsman_runs      37865 non-null  float64
#  13  extra_runs        37865 non-null  float64
#  14  total_runs_y      37865 non-null  float64
#  15  extras_type       2149 non-null   object
# ...

# %%
delivery_df
# Out:
#        match_id        city                 winner  total_runs_x  inning  \
# 124      335982   Bangalore  Kolkata Knight Riders         223.0       2
# 125      335982   Bangalore  Kolkata Knight Riders         223.0       2
# 126      335982   Bangalore  Kolkata Knight Riders         223.0       2
# 127      335982   Bangalore  Kolkata Knight Riders         223.0       2
# 128      335982   Bangalore  Kolkata Knight Riders         223.0       2
# ...         ...         ...                    ...           ...     ...
# 78437    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78438    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78439    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78440    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78441    598028  Dharamsala        Kings XI Punjab         172.0       2
#
#                       batting_team           bowling_team  over  ball  \
# ...

# %%
delivery_df['runs_left']=delivery_df['total_runs_x']-delivery_df['current_score']
# Out:
# <ipython-input-35-da891a150688>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['runs_left']=delivery_df['total_runs_x']-delivery_df['current_score']

# %%
delivery_df['balls_left'] = 126 - ((delivery_df['over']+1) * 6 + (delivery_df['ball']))
# Out:
# <ipython-input-36-84eb9277e736>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['balls_left'] = 126 - ((delivery_df['over']+1) * 6 + (delivery_df['ball']))

# %%
delivery_df['player_dismissed'].unique()
# Out:
# array([nan, 'R Dravid', 'V Kohli', 'JH Kallis', 'W Jaffer', 'MV Boucher',
#        'B Akhil', 'CL White', 'AA Noffke', 'Z Khan', 'SB Joshi', 'K Goel',
#        'JR Hopes', 'Yuvraj Singh', 'KC Sangakkara', 'V Sehwag',
#        'S Chanderpaul', 'LRPL Taylor', 'BB McCullum', 'RT Ponting',
#        'WP Saha', 'SC Ganguly', 'Mohammad Hafeez', 'M Kaif', 'YK Pathan',
#        'Kamran Akmal', 'DS Lehmann', 'G Gambhir', 'L Ronchi',
#        'ST Jayasuriya', 'RV Uthappa', 'SM Pollock', 'DJ Bravo',
#        'MA Khote', 'Harbhajan Singh', 'SR Watson', 'GC Smith',
#        'RA Jadeja', 'D Salunkhe', 'SS Tiwary', 'AM Nayar', 'M Rawat',
#        'PA Patel', 'DPMD Jayawardene', 'SM Katich', 'TM Srivastava',
#        'IK Pathan', 'B Chipli', 'P Kumar', 'DW Steyn', 'AM Rahane',
#        'MK Pandey', 'RR Sarwan', 'Salman Butt', 'AB Agarkar', 'BJ Hodge',
#        'LR Shukla', 'DJ Hussey', 'DB Das', 'Umar Gul', 'AB Dinda',
#        'AC Gilchrist', 'HH Gibbs', 'RG Sharma', 'Shahid Afridi',
# ...

# %%
valid_names=['R Dravid', 'V Kohli', 'JH Kallis', 'W Jaffer', 'MV Boucher',
       'B Akhil', 'CL White', 'AA Noffke', 'Z Khan', 'SB Joshi', 'K Goel',
       'JR Hopes', 'Yuvraj Singh', 'KC Sangakkara', 'V Sehwag',
       'S Chanderpaul', 'LRPL Taylor', 'BB McCullum', 'RT Ponting',
       'WP Saha', 'SC Ganguly', 'Mohammad Hafeez', 'M Kaif', 'YK Pathan',
       'Kamran Akmal', 'DS Lehmann', 'G Gambhir', 'L Ronchi',
       'ST Jayasuriya', 'RV Uthappa', 'SM Pollock', 'DJ Bravo',
       'MA Khote', 'Harbhajan Singh', 'SR Watson', 'GC Smith',
       'RA Jadeja', 'D Salunkhe', 'SS Tiwary', 'AM Nayar', 'M Rawat',
       'PA Patel', 'DPMD Jayawardene', 'SM Katich', 'TM Srivastava',
       'IK Pathan', 'B Chipli', 'P Kumar', 'DW Steyn', 'AM Rahane',
       'MK Pandey', 'RR Sarwan', 'Salman Butt', 'AB Agarkar', 'BJ Hodge',
       'LR Shukla', 'DJ Hussey', 'DB Das', 'Umar Gul', 'AB Dinda',
       'AC Gilchrist', 'HH Gibbs', 'RG Sharma', 'Shahid Afridi',
       'VVS Laxman', 'SB Styris', 'S Dhawan', 'AB de Villiers',
       'Shoaib Malik', 'KD Karthik', 'PJ Sangwan', 'R Bhatia',
       'Mohammad Asif', 'GD McGrath', 'SA Asnodkar', 'SE Marsh',
       'YV Takawale', 'S Vidyut', 'SP Fleming', 'SK Raina', 'JA Morkel',
       'MS Dhoni', 'CK Kapugedera', 'J Arunkumar', 'PP Chawla',
       'VRV Singh', 'DB Ravi Teja', 'SB Bangar', 'WPUJC Vaas',
       'AD Mascarenhas', 'SK Warne', 'MK Tiwary', 'TM Dilshan',
       'MF Maharoof', 'A Mishra', 'VY Mahesh', 'SR Tendulkar',
       'Y Venugopal Rao', 'PP Ojha', 'RP Singh', 'Misbah-ul-Haq',
       'DT Patil', 'A Kumble', 'LPC Silva', 'H Das', 'Sohail Tanvir',
       'DR Smith', 'PR Shah', 'SD Chitnis', 'A Nehra', 'VS Yeligati',
       'S Badrinath', 'MS Gony', 'L Balaji', 'LA Pomersbach', 'A Mukund',
       'A Chopra', 'Younis Khan', 'NK Patel', 'A Flintoff', 'ML Hayden',
       'JDP Oram', 'T Henderson', 'MM Patel', 'Kamran Khan',
       'KP Pietersen', 'R Bishnoi', 'R Vinay Kumar', 'JD Ryder',
       'KV Sharma', 'Joginder Sharma', 'CH Gayle', 'Yashpal Singh',
       'I Sharma', 'RS Bopara', 'JP Duminy', 'RJ Quiney', 'AS Raut',
       'AN Ghosh', 'BAW Mendis', 'PC Valthaty', 'SP Goswami',
       'RE van der Merwe', 'SK Trivedi', 'MN van Wyk', 'NV Ojha',
       'LA Carseldine', 'DA Warner', 'M Manhas', 'S Sohal', 'RJ Harris',
       'TL Suman', 'WA Mota', 'M Vijay', 'M Morkel', 'A Symonds',
       'Shoaib Ahmed', 'DS Kulkarni', 'C Nanda', 'SL Malinga', 'J Botha',
       'A Singh', 'SS Shaikh', 'B Lee', 'AA Bilakhia', 'Anirudh Singh',
       'AA Jhunjhunwala', 'P Dogra', 'A Uniyal', 'JM Kemp', 'R Ashwin',
       'M Muralitharan', 'OA Shah', 'AD Mathews', 'RS Gavaskar',
       'SE Bond', 'M Kartik', 'DP Nannes', 'MS Bisla', 'AB Barath',
       'CA Pujara', 'MC Henriques', 'Y Nagar', 'S Ladda', 'KA Pollard',
       'GJ Bailey', 'J Theron', 'SJ Srivastava', 'R Sathish',
       'EJG Morgan', 'MJ Lumb', 'MD Mishra', 'Jaskaran Singh',
       'KAJ Roach', 'Mandeep Singh', 'CK Langeveldt', 'AT Rayudu',
       'FY Fazal', 'AC Voges', 'S Narwal', 'SW Tait', 'R Sharma',
       'A Mithun', 'Harmeet Singh', 'R McLaren', 'PD Collingwood',
       'KM Jadhav', 'S Sriram', 'AP Dole', 'KP Appanna', 'MR Marsh',
       'Pankaj Singh', 'B Sumanth', 'AG Paunikar', 'DJ Jacobs',
       'IR Jaggi', 'DT Christian', 'AL Menaria', 'Sunny Singh',
       'MA Agarwal', 'JJ van der Wath', 'R Ninan', 'AUK Pathan',
       'AJ Finch', 'STR Binny', 'MEK Hussey', 'S Anirudha', 'S Randiv',
       'TR Birt', 'Bipul Sharma', 'CA Ingram', 'S Nadeem', 'DH Yagnik',
       'AC Blizzard', 'AB McDonald', 'KB Arun Karthik', 'BA Bhatt',
       'JEC Franklin', 'DL Vettori', 'RE Levi', 'GJ Maxwell', 'DJ Harris',
       'Ankit Sharma', 'SP Narine', 'HV Patel', 'KK Cooper', 'AA Chavan',
       'GB Hogg', 'F du Plessis', 'Shakib Al Hasan', 'RN ten Doeschate',
       'N Saini', 'Azhar Mahmood', 'RJ Peterson', 'A Ashish Reddy',
       'Gurkeerat Singh', 'PA Reddy', 'UBT Chand', 'AD Russell',
       'UT Yadav', 'CA Lynn', 'P Negi', 'Sunny Gupta', 'VR Aaron',
       'MC Juneja', 'B Laughlin', 'NLTC Perera', 'Mohammed Shami',
       'BMAJ Mendis', 'GH Vihari', 'SMSM Senanayake', 'KL Rahul',
       'J Syed Mohammad', 'R Dhawan', 'MG Johnson', 'Q de Kock',
       'BB Samantray', 'M Vohra', 'SV Samson', 'DA Miller', 'CH Morris',
       'MM Sharma', 'DJG Sammy', 'BJ Rohrer', 'P Awana', 'JP Faulkner',
       'Sachin Baby', 'AP Tare', 'NM Coulter-Nile', 'CJ Anderson',
       'CM Gautam', 'NJ Maddinson', 'AR Patel', 'JDS Neesham', 'B Kumar',
       'SPD Smith', 'TG Southee', 'PV Tambe', 'KK Nair', 'SA Yadav',
       'BR Dunk', 'RR Rossouw', 'MA Starc', 'KW Richardson', 'S Rana',
       'LMP Simmons', 'Imran Tahir', 'R Shukla', 'R Tewatia', 'SS Iyer',
       'SA Abbott', 'DJ Hooda', 'KS Williamson', 'Iqbal Abdulla',
       'SN Khan', 'D Wiese', 'HH Pandya', 'MJ McClenaghan',
       'Anureet Singh', 'PJ Cummins', 'Karanveer Singh', 'Sandeep Sharma',
       'J Suchith', 'JC Buttler', 'KH Pandya', 'NS Naik', 'JO Holder',
       'Parvez Rasool', 'MP Stoinis', 'Swapnil Singh', 'SW Billings',
       'CR Brathwaite', 'JJ Bumrah', 'HM Amla', 'N Rana', 'RR Pant',
       'F Behardien', 'KJ Abbott', 'C Munro', 'CJ Jordan', 'TM Head',
       'S Aravind', 'TS Mills', 'YS Chahal', 'BCJ Cutting', 'KC Cariappa',
       'C de Grandhomme', 'CR Woakes', 'K Rabada', 'S Badree',
       'MJ Guptill', 'SP Jackson', 'A Choudhary', 'MN Samuels',
       'Kuldeep Yadav', 'DL Chahar', 'MA Wood', 'RK Singh', 'V Shankar',
       'Rashid Khan', 'S Kaul', 'Washington Sundar', 'JJ Roy', 'TA Boult',
       'H Klaasen', 'RA Tripathi', 'BA Stokes', 'K Gowtham', 'JD Unadkat',
       'RK Bhui', 'JC Archer', 'PP Shaw', 'LE Plunkett', 'E Lewis',
       'Ishan Kishan', 'M Markande', 'Mustafizur Rahman', 'AJ Tye',
       'BB Sran', 'AS Rajpoot', 'Shubman Gill', 'Shivam Mavi',
       'MK Lomror', 'DJM Short', 'DR Shorey', 'AD Hales', 'MM Ali',
       'AD Nath', 'TK Curran', 'P Chopra', 'Mohammed Siraj', 'SO Hetmyer',
       'JM Bairstow', 'S Dube', 'P Ray Barman', 'S Gopal', 'S Lamichhane',
       'Mohammad Nabi', 'SD Lad', 'LS Livingstone', 'Abhishek Sharma',
       'KK Ahmed', 'AJ Turner', 'KMA Paul', 'R Parag', 'SN Thakur',
       'SE Rutherford', 'N Pooran', 'GC Viljoen', 'MJ Santner',
       'P Simran Singh', 'Mujeeb Ur Rahman', 'SM Curran', 'PK Garg',
       'RD Gaikwad', 'D Padikkal', 'JR Philippe', 'Navdeep Saini',
       'Ravi Bishnoi', 'Abdul Samad', 'I Udana', 'YBK Jaiswal',
       'SS Cottrell', 'Arshdeep Singh', 'N Jagadeesan', 'T Banton',
       'KL Nagarkoti', 'AT Carey', 'TU Deshpande', 'A Nortje',
       'Kartik Tyagi', 'DR Sams', 'RM Patidar', 'Shahbaz Ahmed',
       'KA Jamieson', 'Virat Singh', 'CV Varun', 'M Prasidh Krishna',
       'Anmolpreet Singh', 'AF Milne', 'RD Chahar', 'VR Iyer',
       'KS Bharat', 'RV Patel', 'Anuj Rawat', 'GD Phillips', 'C Sakariya',
       'TL Seifert', 'R Powell', 'MS Wade', 'R Shepherd', 'DJ Willey',
       'PWH de Silva', 'Tilak Varma', 'TH David', 'M Ashwin',
       'Lalit Yadav', 'AK Markram', 'Rasikh Salam', 'A Badoni',
       'PVD Chameera', 'SS Prabhudessai', 'Akash Deep',
       'HE van der Dussen', 'D Brevis', 'FA Allen', 'A Manohar',
       'AS Joseph', 'D Pretorius', 'B Sai Sudharsan', 'Shashank Singh',
       'B Indrajith', 'DP Conway', 'AS Roy', 'Harshit Rana',
       'Umran Malik', 'Ramandeep Singh', 'K Kartikeya', 'KS Sharma',
       'Mohsin Khan', 'Avesh Khan', 'T Stubbs', 'HR Shokeen', 'M Jansen',
       'R Sanjay Yadav', 'A Tomar', 'Aman Hakim Khan', 'HC Brook',
       'AU Rashid', 'KR Mayers', 'MG Bracewell', 'Abishek Porel',
       'Rahmanullah Gurbaz', 'YV Dhull', 'N Wadhera', 'Dhruv Jurel',
       'WD Parnell', 'PD Salt', 'C Green', 'Arjun Tendulkar',
       'Naveen-ul-Haq', 'Noor Ahmad', 'JE Root', 'A Zampa', 'KM Asif',
       'Sanvir Singh', 'Vishnu Vinod', 'MD Shanaka', 'DG Nalkande',
       'PN Mankad', 'Naman Dhir', 'G Coetzee', 'Azmatullah Omarzai',
       'R Ravindra', 'DJ Mitchell', 'Sameer Rizvi', 'Sumit Kumar',
       'Kumar Kushagra', 'JA Richardson', 'BR Sharath', 'M Shahrukh Khan',
       'J Fraser-McGurk', 'A Raghuvanshi', 'SD Hope', 'R Sai Kishore',
       'Nithish Kumar Reddy', 'AA Kulkarni', 'Yudhvir Singh', 'SB Dubey',
       'D Ferreira', 'T Kohler-Cadmore']

# %%
delivery_df['player_dismissed']=delivery_df['player_dismissed'].apply(lambda x:1 if x in valid_names else 0)
# Out:
# <ipython-input-39-54464a30b759>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['player_dismissed']=delivery_df['player_dismissed'].apply(lambda x:1 if x in valid_names else 0)

# %%
delivery_df['player_dismissed'].head(25)
# Out:
# 124    0
# 125    0
# 126    0
# 127    0
# 128    0
# 129    0
# 130    0
# 131    1
# 132    0
# 133    0
# 134    0
# 135    0
# 136    0
# 137    0
# 138    1
# 139    0
# 140    0
# 141    0
# 142    0
# 143    0
# 144    0
# 145    0
# 146    0
# 147    0
# 148    0
# Name: player_dismissed, dtype: int64

# %%
delivery_df['wickets'] = 10 - delivery_df.groupby('match_id')['player_dismissed'].cumsum()

# Preview the result
delivery_df.head()
# Out:
# <ipython-input-41-e12a30b8329d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['wickets'] = 10 - delivery_df.groupby('match_id')['player_dismissed'].cumsum()
#      match_id       city                 winner  total_runs_x  inning  \
# 124    335982  Bangalore  Kolkata Knight Riders         223.0       2
# 125    335982  Bangalore  Kolkata Knight Riders         223.0       2
# 126    335982  Bangalore  Kolkata Knight Riders         223.0       2
# 127    335982  Bangalore  Kolkata Knight Riders         223.0       2
# 128    335982  Bangalore  Kolkata Knight Riders         223.0       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# ...

# %%
delivery_df['crr']=(delivery_df["current_score"]*6)/(120-delivery_df["balls_left"])
# Out:
# <ipython-input-42-272d6e3c9d08>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['crr']=(delivery_df["current_score"]*6)/(120-delivery_df["balls_left"])

# %%
match_df['city']=delivery_df['city']

# %%
delivery_df['rrr']=(delivery_df['runs_left']*6)/delivery_df['balls_left']
# Out:
# <ipython-input-44-ee198925a9be>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['rrr']=(delivery_df['runs_left']*6)/delivery_df['balls_left']

# %%
delivery_df
# Out:
#        match_id        city                 winner  total_runs_x  inning  \
# 124      335982   Bangalore  Kolkata Knight Riders         223.0       2
# 125      335982   Bangalore  Kolkata Knight Riders         223.0       2
# 126      335982   Bangalore  Kolkata Knight Riders         223.0       2
# 127      335982   Bangalore  Kolkata Knight Riders         223.0       2
# 128      335982   Bangalore  Kolkata Knight Riders         223.0       2
# ...         ...         ...                    ...           ...     ...
# 78437    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78438    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78439    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78440    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78441    598028  Dharamsala        Kings XI Punjab         172.0       2
#
#                       batting_team           bowling_team  over  ball  \
# ...

# %%
def firstInningWin(row):
    return 1 if row['batting_team']==row['winner'] else 0

# %%
delivery_df['firstInningWin']=delivery_df.apply(firstInningWin,axis=1)
# Out:
# <ipython-input-47-7ed5850e94de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['firstInningWin']=delivery_df.apply(firstInningWin,axis=1)

# %%
delivery_df
# Out:
#        match_id        city                 winner  total_runs_x  inning  \
# 124      335982   Bangalore  Kolkata Knight Riders         223.0       2
# 125      335982   Bangalore  Kolkata Knight Riders         223.0       2
# 126      335982   Bangalore  Kolkata Knight Riders         223.0       2
# 127      335982   Bangalore  Kolkata Knight Riders         223.0       2
# 128      335982   Bangalore  Kolkata Knight Riders         223.0       2
# ...         ...         ...                    ...           ...     ...
# 78437    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78438    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78439    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78440    598028  Dharamsala        Kings XI Punjab         172.0       2
# 78441    598028  Dharamsala        Kings XI Punjab         172.0       2
#
#                       batting_team           bowling_team  over  ball  \
# ...

# %%
final_df=delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','firstInningWin']]

# %%
final_df=final_df.sample(final_df.shape[0])

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team      0
# bowling_team      0
# city              0
# runs_left         0
# balls_left        0
# wickets           0
# total_runs_x      0
# crr               0
# rrr               0
# firstInningWin    0
# dtype: int64

# %%
final_df=final_df[final_df['balls_left']!=0]

# %%
x=final_df.iloc[:,:-1]
y=final_df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets         0
# total_runs_x    0
# crr             0
# rrr             0
# dtype: int64

# %%
x_train.describe()
# Out:
#           runs_left    balls_left       wickets  total_runs_x           crr  \
# count  30191.000000  30191.000000  30191.000000  30191.000000  30191.000000
# mean      91.193005     63.255772      7.553907    160.957603      7.124596
# std       48.740271     33.163323      2.138853     28.865087      2.212160
# min      -15.000000     -2.000000      0.000000     68.000000      0.000000
# 25%       53.000000     35.000000      6.000000    142.000000      6.000000
# 50%       90.000000     64.000000      8.000000    162.000000      7.166667
# 75%      128.000000     92.000000      9.000000    180.000000      8.327586
# max      247.000000    119.000000     10.000000    247.000000     36.000000
#
#                 rrr
# count  30191.000000
# mean      10.275336
# std       14.220963
# min     -516.000000
# 25%        6.954545
# 50%        8.653846
# 75%       10.764706
# max      552.000000

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
# Remove the 'sparse' argument and set 'handle_unknown' to 'ignore' for newer versions
trf = ColumnTransformer([
    ('trf', OneHotEncoder(drop='first', handle_unknown='ignore'), ['batting_team', 'bowling_team', 'city'])
], remainder='passthrough')

# %%
#for probablity logistic Regression is best
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe= Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/compose/_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['batting_team',
# ...

# %%
y_pred=pipe.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8240593534711181

# %%
pipe.predict_proba(x_test)[10]
# Out:
# array([0.5757706, 0.4242294])

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Capitals',
#  'Gujarat Titans',
#  'Lucknow Super Giants']

# %%
delivery_df['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi'], dtype=object)

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
